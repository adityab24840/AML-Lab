# %%
import numpy as np
import pandas as pd
import sklearn as sk

import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs, make_circles

from sklearn.cluster import KMeans

# %% [markdown]
# ##### Synthetic data with different range

# %%
blob_centers = np.array(
    [[ 11.2,  6.3],
     [-1.0 ,  6.3],
     [-4.7,  7.8],
     [-8.0,  12.8],
     [-12.5,  13.3]])

blob_std = np.array([0.4, 0.3, 0.6, 0.1, 0.2])

# %%
X, y = make_blobs(n_samples=300, centers=blob_centers,
                  cluster_std=blob_std, random_state=7)

# %%
def plot_clusters(X, y=None):
    #plt.scatter(X[:, 0], X[:, 1], c=y, s=1)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=1, cmap='rainbow')
    plt.xlabel("$x_1$", fontsize=14)
    plt.ylabel("$x_2$", fontsize=14, rotation=0)

# %%
plot_clusters(X, y)

# %%
##### Synthetic data for KMeans

# %%
num_clusters = 4
X, y = make_blobs(n_samples=300, centers=num_clusters, cluster_std=0.6, random_state=0)
plot_clusters(X, y)

# %%
kmeans = KMeans(n_clusters=num_clusters, random_state=42, verbose=1)
kmeans.fit(X)
# Out:
# Initialization complete
# Iteration 0, inertia 309.9340434008142.
# Iteration 1, inertia 212.09699509991452.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 583.5535033679288.
# Iteration 1, inertia 525.6291336481917.
# Iteration 2, inertia 524.0648025416108.
# Iteration 3, inertia 523.7150139149792.
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 277.0847495700475.
# Iteration 1, inertia 213.26430825662953.
# Iteration 2, inertia 212.07066285995737.
# Iteration 3, inertia 212.00599621083478.
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 403.7977657405952.
# Iteration 1, inertia 212.30321585306922.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 275.25198280123095.
# Iteration 1, inertia 212.00599621083478.
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 289.93963174598866.
# Iteration 1, inertia 213.54917356616397.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 434.86028039982443.
# Iteration 1, inertia 214.2111577582559.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 360.08196605746446.
# Iteration 1, inertia 213.2181336735337.
# Iteration 2, inertia 212.07066285995737.
# Iteration 3, inertia 212.00599621083478.
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 286.2694120817409.
# Iteration 1, inertia 212.07066285995737.
# Iteration 2, inertia 212.00599621083478.
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 373.95976491726555.
# Iteration 1, inertia 213.7185159559261.
# Iteration 2, inertia 212.07066285995737.
# Iteration 3, inertia 212.00599621083478.
# Converged at iteration 3: strict convergence.
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42, verbose=1)

# %%
y_pred = kmeans.predict(X)

print("X[i] belongs to cluster:\n", y_pred)
# Out:
# X[i] belongs to cluster:
#  [1 0 2 0 1 1 3 2 0 0 3 0 2 0 1 2 2 1 3 3 1 1 2 3 3 2 1 2 3 2 0 0 2 0 0 0 0
#  0 3 1 2 3 2 2 3 3 0 3 0 1 3 1 0 1 1 3 0 3 0 1 0 2 0 3 3 3 0 1 0 3 2 3 0 3
#  3 0 3 2 1 0 1 2 1 1 0 2 1 2 0 0 2 1 0 3 3 2 1 1 2 3 0 1 0 1 2 1 1 2 0 2 3
#  3 1 0 1 2 0 1 1 2 3 1 3 1 1 1 1 3 1 3 0 3 3 1 0 3 3 0 2 0 0 3 2 3 2 3 0 2
#  0 0 0 2 0 2 1 3 0 3 1 2 0 2 2 1 2 3 3 2 1 2 2 0 1 2 3 0 1 1 2 3 1 2 3 3 2
#  2 2 2 1 0 2 3 2 2 3 3 3 2 3 0 2 3 1 3 2 0 3 0 2 0 2 3 2 2 0 3 3 1 1 2 0 1
#  1 3 1 3 2 0 0 2 2 0 2 1 3 2 1 3 0 3 1 2 1 0 0 0 0 3 3 0 2 3 1 2 3 3 3 1 1
#  0 2 2 3 1 0 3 2 0 2 1 1 3 3 2 1 1 1 2 0 0 1 1 2 1 1 1 0 3 0 2 1 1 0 0 0 1
#  1 2 0 3]

# %%
print("Instance labels:\n", kmeans.labels_)
print("Cluster Centroids:\n", kmeans.cluster_centers_)
print("Inertia: ", kmeans.inertia_)
# Out:
# Instance labels:
#  [1 0 2 0 1 1 3 2 0 0 3 0 2 0 1 2 2 1 3 3 1 1 2 3 3 2 1 2 3 2 0 0 2 0 0 0 0
#  0 3 1 2 3 2 2 3 3 0 3 0 1 3 1 0 1 1 3 0 3 0 1 0 2 0 3 3 3 0 1 0 3 2 3 0 3
#  3 0 3 2 1 0 1 2 1 1 0 2 1 2 0 0 2 1 0 3 3 2 1 1 2 3 0 1 0 1 2 1 1 2 0 2 3
#  3 1 0 1 2 0 1 1 2 3 1 3 1 1 1 1 3 1 3 0 3 3 1 0 3 3 0 2 0 0 3 2 3 2 3 0 2
#  0 0 0 2 0 2 1 3 0 3 1 2 0 2 2 1 2 3 3 2 1 2 2 0 1 2 3 0 1 1 2 3 1 2 3 3 2
#  2 2 2 1 0 2 3 2 2 3 3 3 2 3 0 2 3 1 3 2 0 3 0 2 0 2 3 2 2 0 3 3 1 1 2 0 1
#  1 3 1 3 2 0 0 2 2 0 2 1 3 2 1 3 0 3 1 2 1 0 0 0 0 3 3 0 2 3 1 2 3 3 3 1 1
#  0 2 2 3 1 0 3 2 0 2 1 1 3 3 2 1 1 1 2 0 0 1 1 2 1 1 1 0 3 0 2 1 1 0 0 0 1
#  1 2 0 3]
# Cluster Centroids:
#  [[-1.37324398  7.75368871]
#  [ 1.98258281  0.86771314]
#  [ 0.94973532  4.41906906]
#  [-1.58438467  2.83081263]]
# Inertia:  212.00599621083478

# %%
X_new = np.array([[0, 2], [3, 2], [-3, 1], [-3, 2.5]])
kmeans.predict(X_new)
# Out:
# array([3, 1, 3, 3])

# %%
X_clust1 = X[kmeans.labels_ == 1]
X_clust1[:5]
# Out:
# array([[ 0.83685684,  2.13635938],
#        [ 1.27135141,  1.89254207],
#        [ 3.43761754,  0.26165417],
#        [ 1.45513831, -0.029199  ],
#        [ 2.56936589,  0.5070483 ]])

# %%
mean1=np.mean(X_clust1,axis=0)
var1=np.var(X_clust1,axis=0)
mean1,var1
# Out:
# (array([1.98258281, 0.86771314]), array([0.34029368, 0.34602416]))

# %% [markdown]
# ##### Utility functions for plotting

# %%
def plot_data(X):
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='o', s=30, linewidths=8,
                color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=50, linewidths=50,
                color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
        plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)

# %%
#KMeans producing a linear decision boundary
plt.figure(figsize=(12, 6))
plot_decision_boundaries(kmeans, X)
plt.show()

# %%
def plot_clusterer_comparison(clusterer1, clusterer2, X, title1=None, title2=None):
    clusterer1.fit(X)
    clusterer2.fit(X)

    plt.figure(figsize=(12, 4))

    plt.subplot(121)
    plot_decision_boundaries(clusterer1, X)
    if title1:
        plt.title(title1, fontsize=14)

    plt.subplot(122)
    plot_decision_boundaries(clusterer2, X, show_ylabels=False)
    if title2:
        plt.title(title2, fontsize=14)

# %%
kmeans_rnd_init1 = KMeans(n_clusters=5, init="random", n_init=1,
                         algorithm="full", random_state=11)
kmeans_rnd_init2 = KMeans(n_clusters=5, init="random", n_init=1,
                         algorithm="full", random_state=19)

plot_clusterer_comparison(kmeans_rnd_init1, kmeans_rnd_init2, X,
                          "Solution 1", "Solution 2 (with a different random init)")

plt.show()
# Out:
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:1366: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:1366: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(

# %%
kmeans_rnd_init1 = KMeans(n_clusters=5, init="k-means++", n_init=1,
                         algorithm="full", random_state=11)
kmeans_rnd_init2 = KMeans(n_clusters=5, init="k-means++", n_init=1,
                         algorithm="full", random_state=19)

plot_clusterer_comparison(kmeans_rnd_init1, kmeans_rnd_init2, X,
                          "Solution 1", "Solution 2 (with a different random init)")

# %% [markdown]
# ##### Cross validation to select the right K

# %%
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]

# %%
plt.figure(figsize=(12, 5.5))
plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.annotate('Elbow',
             xy=(4, inertias[3]),
             xytext=(0.55, 0.55),
             textcoords='figure fraction',
             fontsize=16,
             arrowprops=dict(facecolor='black', shrink=0.1)
            )
plt.axis([1, 8.5, 0, 1300])
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_scores = [silhouette_score(X, model.labels_)
                     for model in kmeans_per_k[1:]]

plt.figure(figsize=(10, 4))
plt.plot(range(2, 10), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.axis([1.8, 8.5, 0.55, 0.7])
plt.show()

# %%
import matplotlib as mpl
from sklearn.metrics import silhouette_samples
from matplotlib.ticker import FixedLocator, FixedFormatter

plt.figure(figsize=(11, 9))

for k in (3, 4, 5, 6):
    plt.subplot(2, 2, k - 2)
    
    y_pred = kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(X, y_pred)

    print(len(silhouette_coefficients))
    print(type(silhouette_coefficients))
    print(silhouette_coefficients)
    padding = len(X) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()

        color = mpl.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding

    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (3, 5):
        plt.ylabel("Cluster")
    
    if k in (5, 6):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom=False)

    plt.axvline(x=silhouette_scores[k - 2], color="red", linestyle="--")
    plt.title("$k={}$".format(k), fontsize=16)

plt.show()

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,8))
for i in [2, 3, 4, 5]:
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X)

# %% [markdown]
# ##### Poor man's Image segmentation

# %%
from matplotlib.image import imread
from pylab import *

plt.figure(figsize=(8, 4))
image = imread("nature.jpg") 
imshow(image)
show()

print("Image Shape (3D Array): ", image.shape)
image.dtype
# Out:
# Image Shape (3D Array):  (2192, 3300, 3)
# dtype('uint8')

# %%
X = image.reshape(-1, 3)
print("Dimension of Reshaped X: ", X.shape)
# Out:
# Dimension of Reshaped X:  (7233600, 3)

# %%
kmeans = KMeans(n_clusters=8, random_state=42).fit(X)
# Out:
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
print(f"Label count= {kmeans.labels_.shape}")
print("3D Cluster Center count=", kmeans.cluster_centers_.shape)
print("3D Cluster Centers:\n", kmeans.cluster_centers_)
# Out:
# Label count= (7233600,)
# 3D Cluster Center count= (8, 3)
# 3D Cluster Centers:
#  [[113.2192547  153.97978175 185.12715153]
#  [ 71.38925266  98.52017206  71.96346321]
#  [227.84515038 240.73202615 253.10772597]
#  [ 75.6395697  127.68443259 152.82978316]
#  [ 27.94008413  97.07982794 108.59089748]
#  [ 21.39903114  36.73546538  29.53883671]
#  [127.0785281  144.47768359  87.28707728]
#  [161.96177104 200.88935887 242.83624231]]

# %%
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image)
plt.title("Original image")
plt.axis('off')

plt.subplot(122)
#plt.imshow(segmented_img/255)
plt.imshow((segmented_img * 255).astype(np.uint8))
plt.title("Segmented Image: {} colors".format(8))
show()

# %% [markdown]
# ##### MNIST

# %%
from sklearn.datasets import load_digits

# %%
X_digits, y_digits = load_digits(return_X_y=True)

print(X_digits.shape)
# Out:
# (1797, 64)

# %%
some_digit = X_digits[16]
some_digit_image = some_digit.reshape(8, 8)
plt.imshow(some_digit_image, cmap = 'gray', interpolation="nearest")
plt.show()

# %%
def visualize_digit(img):
    fig = plt.figure(figsize = (8,8)) 
    img = img.reshape(8, 8)
    plt.imshow(img, cmap='gray')
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            plt.annotate(str(round(img[x][y],2)), xy=(y,x),
                        horizontalalignment='center',
                        verticalalignment='center',
                        color='white' if img[x][y]<thresh else 'black')

visualize_digit(X_digits[16])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_digits, y_digits, random_state=42)
print(f"X_train dim {X_train.shape}")
# Out:
# X_train dim (1347, 64)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(multi_class="ovr", solver="lbfgs", max_iter=5000, random_state=42)
lr.fit(X_train, y_train)

accuracy_before_preproc = lr.score(X_test, y_test)
print(f"Accuracy before preproc = {accuracy_before_preproc}")
# Out:
# Accuracy before preproc = 0.9688888888888889

# %% [markdown]
# ##### KMeans for preprocessing

# %%
# Step 1: Choose a number of clusters to be the projected dimension of our features and train the K-Means model.
kmeans = KMeans(n_clusters=50, random_state=42)
kmeans.fit(X_train)


# Step 2: Compute the distance of the data points from each cluster center. 
#         These distances will be the new feature vector.
X_train_new = kmeans.transform(X_train)
X_test_new = kmeans.transform(X_test)

print("Dimension of new features: ", X_train_new.shape)

# Classify the data using the new features
log_reg = LogisticRegression(multi_class="ovr", solver="lbfgs", max_iter=5000, random_state=42)
log_reg.fit(X_train_new, y_train)


accuracy_after_preproc = log_reg.score(X_test_new, y_test)
print("Accuracy after preproc = ", accuracy_after_preproc)
# Out:
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Dimension of new features:  (1347, 50)
# Accuracy after preproc =  0.9777777777777777

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ("kmeans", KMeans(n_clusters=50, random_state=42)),
    ("lr", LogisticRegression(multi_class="ovr", solver="lbfgs", max_iter=5000, random_state=42)),
])
pipeline.fit(X_train, y_train)

accuracy_after_preproc = pipeline.score(X_test, y_test)

print(f"Accuracy after preproc = {accuracy_after_preproc}")

reduction_in_error = 1 - (1 - accuracy_after_preproc) / (1 - accuracy_before_preproc)
print("Reduction in Error Rate: %f" %  reduction_in_error)
# Out:
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy after preproc = 0.9777777777777777
# Reduction in Error Rate: 0.285714

# %%
from sklearn.model_selection import GridSearchCV
param_grid = dict(kmeans__n_clusters=range(2, 100))
grid_clf = GridSearchCV(pipeline, param_grid, cv=3, verbose=1, n_jobs=-1)
grid_clf.fit(X_train, y_train)

params_optimal_grid_clf = grid_clf.best_params_

print("Optimal Hyperparameter Values: ", params_optimal_grid_clf)
print("Grid Accuracy: ", grid_clf.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 98 candidates, totalling 294 fits
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Optimal Hyperparameter Values:  {'kmeans__n_clusters': 75}
# Grid Accuracy:  0.9844444444444445

# %%
print("Optimal Number of Clusters: ", params_optimal_grid_clf['kmeans__n_clusters'])

pipeline = Pipeline([
    ("kmeans", KMeans(n_clusters=params_optimal_grid_clf['kmeans__n_clusters'], random_state=42)),
    ("log_reg", LogisticRegression(multi_class="ovr", solver="lbfgs", max_iter=5000, random_state=42)),
])
pipeline.fit(X_train, y_train)

accuracy_after_preproc = pipeline.score(X_test, y_test)

print("Accuracy after preproc: ", accuracy_after_preproc)

reduction_in_error = 1 - (1 - accuracy_after_preproc) / (1 - accuracy_before_preproc)
print("Reduction in Error Rate: %f" %  reduction_in_error)
# Out:
# Optimal Number of Clusters:  75
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy after preproc:  0.9844444444444445
# Reduction in Error Rate: 0.500000

# %% [markdown]
# ##### Gaussian Mixture Models

# %%
X1, y1 = make_blobs(n_samples=1000, centers=((4, -4), (0, 0)), random_state=42)
X1 = X1.dot(np.array([[0.374, 0.95], [0.732, 0.598]]))
X2, y2 = make_blobs(n_samples=250, centers=1, random_state=42)
X2 = X2 + [6, -8]
X = np.r_[X1, X2]
y = np.r_[y1, y2]

# %%
def plot_clusters(X, y=None):
    plt.scatter(X[:, 0], X[:, 1], c=y, s=5, cmap='autumn')
    plt.xlabel("$x_1$", fontsize=14)
    plt.ylabel("$x_2$", fontsize=14, rotation=0)
    
plt.figure(figsize=(12, 6))
plot_clusters(X)
plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_21708\3765311429.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], c=y, s=5, cmap='autumn')

# %%
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=3, n_init=10, random_state=42)
gmm.fit(X)
# Out:
# GaussianMixture(n_components=3, n_init=10, random_state=42)

# %%
dir(gmm)

# %%
from matplotlib.colors import LogNorm
def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='o', s=30, linewidths=8,
                color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=50, linewidths=50,
                color=cross_color, zorder=11, alpha=1)


def plot_gaussian_mixture(clusterer, X, resolution=1000, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = -clusterer.score_samples(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z,
                 norm=LogNorm(vmin=1.0, vmax=30.0),
                 levels=np.logspace(0, 2, 12))
    plt.contour(xx, yy, Z,
                norm=LogNorm(vmin=1.0, vmax=30.0),
                levels=np.logspace(0, 2, 12),
                linewidths=1, colors='k')

    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contour(xx, yy, Z,
                linewidths=2, colors='r', linestyles='dashed')
    
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)
    plot_centroids(clusterer.means_, clusterer.weights_)

    plt.xlabel("$x_1$", fontsize=14)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)

# %%
# Compute the log-likelihood of each sample
densities = gmm.score_samples(X)

# Define the threshold is at the fourth percentile lowest density
density_threshold = np.percentile(densities, 4) 

# Get the anomalous samples
anomalies = X[densities < density_threshold]

# %%
plt.figure(figsize=(12, 6))
plt.title("Anomalies (red stars) Reside in the Low-Density Regions")

plot_gaussian_mixture(gmm, X)
plt.scatter(anomalies[:, 0], anomalies[:, 1], color='r', marker='*')
plt.ylim(top=5.1)

plt.show()

# %% [markdown]
# ##### Decision boundary for mixture models

# %%
X1, y1 = make_blobs(n_samples=1000, centers=((4, -4), (0, 0)), random_state=42)
X1 = X1.dot(np.array([[0.374, 0.95], [0.732, 0.598]]))
X2, y2 = make_blobs(n_samples=250, centers=1, random_state=42)
X2 = X2 + [6, -8]
X = np.r_[X1, X2]
y = np.r_[y1, y2]


plt.figure(figsize=(12, 6))
plt.scatter(X[:, 0], X[:, 1], c=None, s=2, cmap='autumn')
plt.xlabel("$x_1$", fontsize=14)
plt.ylabel("$x_2$", fontsize=14, rotation=0)
plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_21708\3823662884.py:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], c=None, s=2, cmap='autumn')

# %%
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X)
                for k in range(1, 10)]



silhouette_scores = [silhouette_score(X, model.labels_)
                     for model in kmeans_per_k[1:]]

plt.figure(figsize=(10, 4))
plt.plot(range(2, 10), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.show()
# Out:
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Number of clusters
k = 3

# Train the K-Means model
kmeans = KMeans(n_clusters=k, random_state=42, verbose=1)
kmeans.fit(X)
# Out:
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 3966.268336935264.
# Iteration 1, inertia 2378.970844598221.
# Iteration 2, inertia 2195.2229891644783.
# Iteration 3, inertia 2181.6234810905503.
# Iteration 4, inertia 2179.6464240399723.
# Iteration 5, inertia 2179.5022566236926.
# Converged at iteration 5: center shift 3.6285040591545244e-05 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2508.3070772026213.
# Iteration 1, inertia 2454.5683820476747.
# Iteration 2, inertia 2417.9489040039907.
# Iteration 3, inertia 2347.6069670004194.
# Iteration 4, inertia 2279.8746284734.
# Iteration 5, inertia 2234.0586590301245.
# Iteration 6, inertia 2203.196957614122.
# Iteration 7, inertia 2189.8042663252218.
# Iteration 8, inertia 2183.8476066662633.
# Iteration 9, inertia 2180.9286126412203.
# Iteration 10, inertia 2180.149032489141.
# Iteration 11, inertia 2179.8058104108477.
# Converged at iteration 11: center shift 0.00012974354240422427 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2584.96645286315.
# Iteration 1, inertia 2252.081081980773.
# Iteration 2, inertia 2243.719017828839.
# Iteration 3, inertia 2242.459700324802.
# Iteration 4, inertia 2242.17552294169.
# Converged at iteration 4: center shift 6.196229217555121e-05 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2810.754339997281.
# Iteration 1, inertia 2245.2722090395687.
# Iteration 2, inertia 2243.2585178214954.
# Iteration 3, inertia 2242.6179130043406.
# Converged at iteration 3: center shift 0.00015645458208555835 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2658.7448306432384.
# Iteration 1, inertia 2251.365609247318.
# Iteration 2, inertia 2243.8946037137757.
# Iteration 3, inertia 2242.9119967127426.
# Iteration 4, inertia 2242.125065545628.
# Converged at iteration 4: center shift 0.0002176413561271141 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2917.4810303386894.
# Iteration 1, inertia 2348.1405210881207.
# Iteration 2, inertia 2267.6946307137837.
# Iteration 3, inertia 2248.884859809042.
# Iteration 4, inertia 2244.041545596917.
# Iteration 5, inertia 2242.7603466187297.
# Converged at iteration 5: center shift 0.00025764000878533504 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 3798.7068890714218.
# Iteration 1, inertia 2919.6235119020826.
# Iteration 2, inertia 2502.0739453415263.
# Iteration 3, inertia 2334.3763318395086.
# Iteration 4, inertia 2249.9786694352456.
# Iteration 5, inertia 2217.415330448522.
# Iteration 6, inertia 2202.145702673776.
# Iteration 7, inertia 2195.155330523254.
# Iteration 8, inertia 2190.434852205698.
# Iteration 9, inertia 2187.691239874134.
# Iteration 10, inertia 2184.438366042676.
# Iteration 11, inertia 2180.8762127663513.
# Iteration 12, inertia 2180.3757007892623.
# Converged at iteration 12: center shift 0.00011157454471783862 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 4801.943171572681.
# Iteration 1, inertia 2364.5794210810805.
# Iteration 2, inertia 2267.6946307137837.
# Iteration 3, inertia 2248.884859809042.
# Iteration 4, inertia 2244.041545596917.
# Iteration 5, inertia 2242.7603466187297.
# Converged at iteration 5: center shift 0.00025764000878533775 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 2691.7012390126606.
# Iteration 1, inertia 2255.4032560957007.
# Iteration 2, inertia 2223.7639432638116.
# Iteration 3, inertia 2210.243243789073.
# Iteration 4, inertia 2202.0847166183053.
# Iteration 5, inertia 2196.064082401785.
# Iteration 6, inertia 2192.1672345742327.
# Iteration 7, inertia 2189.2297864433644.
# Iteration 8, inertia 2185.8097629948847.
# Iteration 9, inertia 2182.0258840371375.
# Iteration 10, inertia 2180.497085605448.
# Iteration 11, inertia 2180.270106223909.
# Iteration 12, inertia 2180.025987588569.
# Converged at iteration 12: center shift 0.00018059643031938033 within tolerance 0.0002732132474543051.
# Initialization complete
# Iteration 0, inertia 3418.176071241477.
# Iteration 1, inertia 2255.591604544778.
# Iteration 2, inertia 2240.9231053455433.
# Iteration 3, inertia 2235.014137540864.
# Iteration 4, inertia 2228.86990936018.
# Iteration 5, inertia 2221.6330420440545.
# Iteration 6, inertia 2213.6576443883823.
# Iteration 7, inertia 2205.607902599635.
# Iteration 8, inertia 2198.7706732867046.
# Iteration 9, inertia 2194.20448326841.
# Iteration 10, inertia 2190.9843467698765.
# Iteration 11, inertia 2187.878388659355.
# Iteration 12, inertia 2183.3628202210784.
# Iteration 13, inertia 2180.5853307308707.
# Iteration 14, inertia 2180.3448549542736.
# Converged at iteration 14: center shift 9.379830199099265e-05 within tolerance 0.0002732132474543051.
# KMeans(n_clusters=3, random_state=42, verbose=1)

# %%
plt.figure(figsize=(12, 6))
plt.title("Clustering by K-Means")
plot_decision_boundaries(kmeans, X)
plt.show()

# %%
gm = GaussianMixture(n_components=3, n_init=10)
gm.fit(X)
# Out:
# GaussianMixture(n_components=3, n_init=10)

# %%
plt.figure(figsize=(12, 6))
plt.title("Clustering by GMM")
plot_decision_boundaries(gm, X, show_centroids=False)
plt.show()

# %% [markdown]
# ##### DBSCAN for non globular data

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=1000, noise=0.05, random_state=42)


plt.figure(figsize=(12, 6))
plt.scatter(X[:, 0], X[:, 1], c=None, s=5, cmap='autumn')
plt.title("Two Arbitrary Shape Clusters", fontsize=16)
plt.xlabel("$x_1$", fontsize=14)
plt.ylabel("$x_2$", fontsize=14, rotation=0)
plt.show()
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_21708\780380561.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], c=None, s=5, cmap='autumn')

# %%
# Number of clusters
k = 2

# Train the K-Means model
kmeans = KMeans(n_clusters=k, random_state=42, verbose=1)
kmeans.fit(X)
# Out:
# c:\Users\adity\anaconda3\envs\pycaretenv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 766.5972350707408.
# Iteration 1, inertia 405.9789795359481.
# Iteration 2, inertia 404.3973876810152.
# Iteration 3, inertia 404.032943496093.
# Iteration 4, inertia 403.7789362907491.
# Iteration 5, inertia 403.70226563162123.
# Converged at iteration 5: center shift 4.513686124073829e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 1153.2847284936886.
# Iteration 1, inertia 415.6939206559983.
# Iteration 2, inertia 404.2393979608081.
# Iteration 3, inertia 403.70594480520515.
# Converged at iteration 3: center shift 2.4933612131190646e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 760.1527081729402.
# Iteration 1, inertia 462.72726163423266.
# Iteration 2, inertia 408.0195281575095.
# Iteration 3, inertia 403.7763452208897.
# Iteration 4, inertia 403.6924699271791.
# Converged at iteration 4: center shift 2.324978969376308e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 822.3128938274972.
# Iteration 1, inertia 445.1549274903151.
# Iteration 2, inertia 416.55937293662896.
# Iteration 3, inertia 407.1900033592349.
# Iteration 4, inertia 404.8098814657993.
# Iteration 5, inertia 404.3671806554538.
# Iteration 6, inertia 404.0734483828587.
# Iteration 7, inertia 403.7989044598227.
# Iteration 8, inertia 403.71808984419846.
# Converged at iteration 8: center shift 4.5073283240231596e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 490.9090363350524.
# Iteration 1, inertia 405.72447877963174.
# Iteration 2, inertia 404.1043724492659.
# Iteration 3, inertia 403.87568778311925.
# Iteration 4, inertia 403.71808984419846.
# Converged at iteration 4: center shift 4.507328324023264e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 524.1938181666532.
# Iteration 1, inertia 405.9836344546833.
# Iteration 2, inertia 404.3692147189329.
# Iteration 3, inertia 404.08130555910554.
# Iteration 4, inertia 403.8247948971322.
# Iteration 5, inertia 403.71808984419846.
# Converged at iteration 5: center shift 4.507328324023149e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 845.7504957465349.
# Iteration 1, inertia 438.2894467797331.
# Iteration 2, inertia 413.3117872916406.
# Iteration 3, inertia 406.370855714334.
# Iteration 4, inertia 404.5220164249544.
# Iteration 5, inertia 404.21493030701015.
# Iteration 6, inertia 403.969154157396.
# Iteration 7, inertia 403.7617200688419.
# Iteration 8, inertia 403.6934822864332.
# Converged at iteration 8: center shift 2.756458158079891e-05 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 769.5255372938873.
# Iteration 1, inertia 416.140803101249.
# Iteration 2, inertia 406.9766202915498.
# Iteration 3, inertia 404.24583530393915.
# Iteration 4, inertia 403.76669500735034.
# Iteration 5, inertia 403.70863181997987.
# Converged at iteration 5: center shift 7.038981135333933e-06 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 676.779970318305.
# Iteration 1, inertia 413.34148656381797.
# Iteration 2, inertia 404.3477174185661.
# Iteration 3, inertia 403.75545935620517.
# Iteration 4, inertia 403.70863181997987.
# Converged at iteration 4: center shift 7.03898113533415e-06 within tolerance 4.995223022533364e-05.
# Initialization complete
# Iteration 0, inertia 776.8236286516391.
# Iteration 1, inertia 461.4365513344494.
# Iteration 2, inertia 421.54495657976867.
# Iteration 3, inertia 407.89183965918426.
# Iteration 4, inertia 404.8571676216597.
# Iteration 5, inertia 404.3992616671667.
# Iteration 6, inertia 404.10914095378206.
# Iteration 7, inertia 403.8961900923375.
# Iteration 8, inertia 403.71808984419846.
# Converged at iteration 8: center shift 4.507328324023149e-05 within tolerance 4.995223022533364e-05.
# KMeans(n_clusters=2, random_state=42, verbose=1)

# %%
plt.figure(figsize=(12, 6))
plt.title("Clustering by K-Means")
plot_decision_boundaries(kmeans, X)
plt.show()

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.15, min_samples=5)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.15)

# %%
def plot_dbscan(dbscan, X, size, show_xlabels=True, show_ylabels=True):
    core_mask = np.zeros_like(dbscan.labels_, dtype=bool)
    core_mask[dbscan.core_sample_indices_] = True
    anomalies_mask = dbscan.labels_ == -1
    non_core_mask = ~(core_mask | anomalies_mask)

    cores = dbscan.components_
    anomalies = X[anomalies_mask]
    non_cores = X[non_core_mask]
    
    plt.scatter(cores[:, 0], cores[:, 1],
                c=dbscan.labels_[core_mask], marker='o', s=size, cmap="Paired")
    plt.scatter(cores[:, 0], cores[:, 1], marker='*', s=20, c=dbscan.labels_[core_mask])
    plt.scatter(anomalies[:, 0], anomalies[:, 1],
                c="r", marker="x", s=100)
    plt.scatter(non_cores[:, 0], non_cores[:, 1], c=dbscan.labels_[non_core_mask], marker=".")
    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)
    plt.title("Clustering by DBSCAN\neps={:.2f}, min_samples={}".format(dbscan.eps, dbscan.min_samples), fontsize=14)

# %%
plt.figure(figsize=(12, 6))
plot_dbscan(dbscan, X, size=100)
plt.show()
